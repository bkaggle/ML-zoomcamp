# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df['median_house_value']
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df = df[df['ocean_proximity'].isin(['<1H OCEAN','INLAND'])]

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 701      -121.97     37.64                32.0       1283.0           194.0
# 830      -121.99     37.61                 9.0       3666.0           711.0
# 859      -121.97     37.57                21.0       4342.0           783.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 861      -121.98     37.58                20.0       4126.0          1031.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
new_columns=['latitude','longitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value']

# %%
df=df[new_columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         37.64    -121.97                32.0       1283.0           194.0
# 1         37.61    -121.99                 9.0       3666.0           711.0
# 2         37.57    -121.97                21.0       4342.0           783.0
# 3         37.58    -121.96                15.0       3575.0           597.0
# 4         37.58    -121.98                20.0       4126.0          1031.0
# ...         ...        ...                 ...          ...             ...
# 15682     39.48    -121.09                25.0       1665.0           374.0
# 15683     39.49    -121.21                18.0        697.0           150.0
# 15684     39.43    -121.22                17.0       2254.0           485.0
# 15685     39.43    -121.32                18.0       1860.0           409.0
# 15686     39.37    -121.24                16.0       2785.0           616.0
#
# ...

# %%
# 1) total_bedrooms
df.isna().sum()
# Out:
# latitude                0
# longitude               0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        157
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %%
# 2) median of df['population']
df['population'].median()
# Out:
# 1195.0

# %%
n=len(df)
n
# Out:
# 15687

# %%
idx = np.arange(n)

# %%
np.random.seed(42)
np.random.shuffle(idx)

# %%
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test
n_train, n_val, n_test
# Out:
# (9413, 3137, 3137)

# %%
df.isna().sum()
# Out:
# latitude                0
# longitude               0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        157
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %%
df1 = df.copy()

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_val+n_train:]]
len(df_train), len(df_val), len(df_test)
# Out:
# (9413, 3137, 3137)

# %%
df_train
# Out:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 15183     36.23    -119.14                22.0       2935.0           523.0
# 4469      34.12    -117.79                16.0       2426.0           426.0
# 9316      33.68    -117.97                26.0       3653.0           568.0
# 4983      34.10    -118.03                32.0       2668.0           609.0
# 13154     37.34    -121.87                39.0       2479.0           541.0
# ...         ...        ...                 ...          ...             ...
# 15377     34.44    -119.15                33.0       2005.0           392.0
# 15225     36.13    -119.13                28.0       1673.0           385.0
# 5231      34.13    -118.08                46.0       1238.0           147.0
# 2076      34.29    -118.46                24.0       3668.0           890.0
# 4103      34.00    -118.41                18.0       1307.0           441.0
#
# ...

# %%
df_train=df_train.reset_index(drop=True)
df_val=df_val.reset_index(drop=True)
df_test=df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train['median_house_value'].values)
y_val = np.log1p(df_val['median_house_value'].values)
y_test = np.log1p(df_test['median_house_value'].values)

# %%
y_train
# Out:
# array([11.16196275, 12.32163544, 12.4718963 , ..., 13.12236738,
#        12.11888489, 12.52924613])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# %%
def calculate_score(df, replace = 0):
    df = df.copy()
    df['total_bedrooms'].fillna(replace, inplace = True)
    df_train = df.iloc[idx[:n_train]]
    df_val = df.iloc[idx[n_train:n_train+n_val]]
    df_test = df.iloc[idx[n_val+n_train:]]
    
    df_train=df_train.reset_index(drop=True)
    df_val=df_val.reset_index(drop=True)
    df_test=df_test.reset_index(drop=True)
    
    y_train = np.log1p(df_train['median_house_value'].values)
    y_val = np.log1p(df_val['median_house_value'].values)
    y_test = np.log1p(df_test['median_house_value'].values)
    
    del df_train['median_house_value']
    del df_val['median_house_value']
    del df_test['median_house_value']
    
    X_train = df_train.values
    X_val = df_val.values
    X_test = df_test.values
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_train)
    
    score = round(mean_squared_error(y_train,y_pred),2)
    
    return score

# %%
rmse_with_fill_zero =calculate_score(df)
rmse_with_fill_zero
# Out:
# 0.12

# %%
mean = df_train['total_bedrooms'].mean()
mean
# Out:
# 542.552956325786

# %%
rmse_with_fill_mean = calculate_score(df, replace=mean)
rmse_with_fill_mean
# Out:
# 0.12

# %%
#3) Both are equally good

# %%
df.isna().sum()
# Out:
# latitude                0
# longitude               0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        157
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %%
def calculate_score(df):
    score = {}
    for r in [0, 0.000001, 0.0001, 0.001, 0.01, 0.1, 1, 5, 10]:
        df = df.copy()
        df['total_bedrooms'].fillna(0, inplace = True)
        df_train = df.iloc[idx[:n_train]]
        df_val = df.iloc[idx[n_train:n_train+n_val]]
        df_test = df.iloc[idx[n_val+n_train:]]

        df_train=df_train.reset_index(drop=True)
        df_val=df_val.reset_index(drop=True)
        df_test=df_test.reset_index(drop=True)

        y_train = np.log1p(df_train['median_house_value'].values)
        y_val = np.log1p(df_val['median_house_value'].values)
        y_test = np.log1p(df_test['median_house_value'].values)

        del df_train['median_house_value']
        del df_val['median_house_value']
        del df_test['median_house_value']

        X_train = df_train.values
        X_val = df_val.values
        X_test = df_test.values

        model = Ridge(alpha=r)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_train)

        rmse = mean_squared_error(y_train,y_pred)
        score[r] = rmse
    
    return score

# %%
calculate_score(df)
# Out:
# {0: 0.1157850146449503,
#  1e-06: 0.11578501464495022,
#  0.0001: 0.11578501464495028,
#  0.001: 0.11578501464495633,
#  0.01: 0.1157850146455544,
#  0.1: 0.11578501470536025,
#  1: 0.1157850206810794,
#  5: 0.11578516500865971,
#  10: 0.11578561341897918}

# %%
help(LinearRegression)
# Out:
# Help on class LinearRegression in module sklearn.linear_model._base:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, default=None
# ...

# %%
#@ FUNCTION FOR RMSE VALUES:
def rmse(y, y_pred):
    error = y_pred - y
    mse = (error ** 2).mean()
    return np.sqrt(mse)

# %%
#@ DEFINING FUNCTION:
def prepare_X(df, fillna_value):
    df_num = df[check]
    df_num = df_num.fillna(fillna_value)
    X = df_num.values
    return X

# %%
#@ FUNCTION FOR TRAINING LINEAR REGRESSION:
def train_linear_regression_reg(X, y, r=0.0):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    reg = r * np.eye(XTX.shape[0])
    XTX = XTX + reg

    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
#@ FILLING MISSING VALUES:
mean = df_train.total_bedrooms.mean()

X_mean_train = prepare_X(df_train, fillna_value=mean)
w_0_mean, w_mean = train_linear_regression(X_mean_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       1 #@ FILLING MISSING VALUES:
#       2 mean = df_train.total_bedrooms.mean()
# ----> 4 X_mean_train = prepare_X(df_train, fillna_value=mean)
#       5 w_0_mean, w_mean = train_linear_regression(X_mean_train, y_train)
#
# Cell In[70], line 3, in prepare_X(df, fillna_value)
#       2 def prepare_X(df, fillna_value):
# ----> 3     df_num = df[check]
#       4     df_num = df_num.fillna(fillna_value)
#       5     X = df_num.values
#
# NameError: name 'check' is not defined
